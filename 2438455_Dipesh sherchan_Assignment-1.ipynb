# %%
#connecting to drive files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import seaborn as sns

# %% [markdown]
# # **3.1 Problem- 1: Getting Started with Data Exploration- Some Warm up Exercises:**

# %% [markdown]
# ## 1. Data Exploration and Understanding:

# %% [markdown]
# ### • Dataset Overview:

# %% [markdown]
# 1. Load the dataset and display the first 10 rows.

# %%
df= pd.read_csv('/content/drive/MyDrive/WHR-2024-5CS037.csv')
#coursework csv file connection/loading the data

# %%
df.head(10)
#using df.head(10) to display the 1st ten rows of datas
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# 2. Identify the number of rows and columns in the dataset.

# %%
rows = len(df.axes[0])
#axes-0 to access rows
column = len(df.axes[1])
#axes-1 to access columns
print("Number of Rows: "+str(rows))# type casting for concatination
print("Number of Columns : "+str(column))
# Out:
# Number of Rows: 143
# Number of Columns : 9

# %% [markdown]
# 3. List all the columns and their data types.

# %%
df.info()
#columns & their d.type listed using df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country name                  143 non-null    object
#  1   score                         143 non-null    float64
#  2   Log GDP per capita            140 non-null    float64
#  3   Social support                140 non-null    float64
#  4   Healthy life expectancy       140 non-null    float64
#  5   Freedom to make life choices  140 non-null    float64
#  6   Generosity                    140 non-null    float64
#  7   Perceptions of corruption     140 non-null    float64
#  8   Dystopia + residual           140 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 10.2+ KB

# %% [markdown]
# ### • Basic Statistics:

# %% [markdown]
# 1. Calculate the mean, median, and standard deviation for the Score column.

# %%
#To print mean of all columns- print(df.mean(numeric_only=True))
#To print median of all columns- print(df.median(numeric_only=True))
#To print standard.d of all columns- print(df.std(numeric_only=True))

score_mean=df.score.mean() #mean of score column
score_median=df.score.median() #median of score column
score_sd=df.score.std() #standard deviation of score column

print("The mean of score is: "+str(score_mean))
print("The median of score is: "+str(score_median))
print("The Standard deviation of score is: "+str(score_sd))
# Out:
# The mean of score is: 5.52758041958042
# The median of score is: 5.785
# The Standard deviation of score is: 1.1707165099442995

# %% [markdown]
# 2. Identify the country with the highest and lowest happiness scores.

# %%
highest_happiness_score=df.score.max() #maximum value of score
lowest_happiness_score=df.score.min() #minimum value of score
highest_country=df.loc[df['score']==highest_happiness_score,'Country name'] #coutry name relating to max value of score
lowest_country=df.loc[df['score']==lowest_happiness_score,'Country name']#country name relating to min value of score
print("Highest happiness score is: "+highest_country)
print("Lowest happiness score is: "+lowest_country)
# Out:
# 0    Highest happiness score is: Finland
# Name: Country name, dtype: object
# 142    Lowest happiness score is: Afghanistan
# Name: Country name, dtype: object

# %% [markdown]
# ### • Missing Values:

# %% [markdown]
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
null_check = df.isnull().sum() # checking each columns and performing sum of nulls
print(null_check)
# Out:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# ### • Filtering and Sorting:

# %% [markdown]
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.

# %%
filtered_data=df[df['score']>7.5] # filtering/conditioning
print('score greater than 7.5:')
filtered_data
# Out:
# score greater than 7.5:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %% [markdown]
# 2. For the filtered dataset- Sort the dataset by GDP per Capita in descending order and display the
#  top 10 rows.

# %%
descending_gdp_filtered_data=filtered_data.sort_values(by='Log GDP per capita', ascending=False)
#using filtered data(variable).sort_values(by='column-name',ascending=False(descending))
descending_gdp_filtered_data.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %% [markdown]
# ### • Adding New Columns:

# %% [markdown]
# 1. Create a new column called Happiness Category that categorizes countries into three categories
#  based on their Score:
#  Low −(Score < 4)
#  Medium −(4 ≤ Score ≤ 6)
#  High −(Score > 6)

# %%
df['Happiness_category']=pd.cut(df['score'],bins=[0,4,6,float('inf')], labels=["low","medium","high"])
#-creating column--using pd.cut()--column_name--distance from these values----categorising acourding to distance
print(df['Happiness_category'])
#printing the column
# Out:
# 0      high
# 1      high
# 2      high
# 3      high
# 4      high
#        ...
# 138     low
# 139     low
# 140     low
# 141     low
# 142     low
# Name: Happiness_category, Length: 143, dtype: category
# Categories (3, object): ['low' < 'medium' < 'high']

# %% [markdown]
# ## 2. Data Visualizations:

# %% [markdown]
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.

# %%
df_sorted = df.sort_values('score', ascending=False).head(10)

#df_sorted.head(10)

plt.figure(figsize=(8,4))#size of the bar plot
plt.bar(df_sorted['Country name'], df_sorted['score'], color='skyblue')

# Adding titles and labels
plt.title('Top 10 Happiest Countries by Score', fontsize=14)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
df_sorted_unhappy= df.sort_values('score', ascending=True).head(10)

#df_sorted.head(10)
# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(df_sorted_unhappy['Country name'], df_sorted_unhappy['score'], marker='o', color='red', linestyle='-', linewidth=2)

# Adding titles and labels
plt.title('Top 10 Unhappiest Countries by Score', fontsize=14)
plt.xlabel('Country name', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)
plt.xticks(rotation=45, ha='right')  # Rotate x labels for better readability

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
#  • Plot a histogram for the Score column to show its distribution and also interpret.

# %%
# Plot the histogram using Pandas (automatically uses Matplotlib)
df['score'].plot(kind='hist', bins=10, color='lightblue', edgecolor='black', figsize=(10, 6))

# Adding titles and labels
plt.title('Distribution of Happiness Scores', fontsize=14)
plt.xlabel('Happiness Score', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
# Scatter plot between GDP per Capita and Score
plt.figure(figsize=(10, 6))
plt.scatter(df['Log GDP per capita'], df['score'], color='green')

# Adding titles and labels
plt.title('Scatter Plot between GDP per Capita and Happiness Score', fontsize=14)
plt.xlabel('GDP per Capita (USD)', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # **3.2 Problem- 2- Some Advance Data Exploration Task:**

# %% [markdown]
# ## Task- 1- Setup Task- Preparing the South-Asia Dataset:

# %% [markdown]
#  1. Define the countries in South Asia with a list for example:
#  south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
#  "Maldives", "Nepal", "Pakistan", "Srilanka"]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/WHR-2024-5CS037.csv')
df.head(15)
# Out:
#    Country name  score  Log GDP per capita  Social support  \
# 0       Finland  7.741               1.844           1.572
# 1       Denmark  7.583               1.908           1.520
# 2       Iceland  7.525               1.881           1.617
# 3        Sweden  7.344               1.878           1.501
# 4        Israel  7.341               1.803           1.513
# 5   Netherlands  7.319               1.901           1.462
# 6        Norway  7.302               1.952           1.517
# 7    Luxembourg  7.122               2.141           1.355
# 8   Switzerland  7.060               1.970           1.425
# 9     Australia  7.057               1.854           1.461
# 10  New Zealand  7.029               1.810           1.527
# 11   Costa Rica  6.955               1.561           1.373
# 12       Kuwait  6.951               1.845           1.364
# 13      Austria  6.905               1.885           1.336
# 14       Canada  6.900               1.840           1.459
#
# ...

# %%
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
                         "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

# %% [markdown]
#  2. Use the list from step- 1 to filtered the dataset {i.e. filtered out matching dataset from list.}

# %%
filtered_data = df[df['Country name'].isin(south_asian_countries)]
filtered_data.head(10)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 3. Save the filtered dataframe as separate CSV files for future use

# %%
filtered_data.to_csv("south_asian_dataset.csv", index=False)

# %% [markdown]
# ## Task- 2- Composite Score Ranking:

# %% [markdown]
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
#  following metrics:
#  Composite Score = 0.40×GDP per Capita+0.30×Social Support
#  +0.30 ×Healthy Life Expectancy

# %%
southasia=pd.read_csv('/content/south_asian_dataset.csv')
southasia.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
#    Perceptions of corruption  Dystopia + residual
# ...

# %%
southasia['Composite Score'] = (0.40 * southasia['Log GDP per capita']) + (0.30 * southasia['Social support']) + (0.30 * southasia['Healthy life expectancy'])
southasia.head()
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
#
#    Perceptions of corruption  Dystopia + residual  Composite Score
# 0                      0.115                1.783           0.8159
# ...

# %% [markdown]
# 2. Rank the South Asian countries based on the Composite Score in descending order.

# %%
df_sorted = southasia.sort_values(by='Composite Score', ascending=False)
df_sorted.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 3    Sri Lanka  3.898               1.361           1.179
# 0        Nepal  5.158               0.965           0.990
# 2        India  4.054               1.166           0.653
# 1     Pakistan  4.657               1.069           0.600
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 3                    0.586                         0.583       0.144
# 0                    0.443                         0.653       0.209
# 2                    0.417                         0.767       0.174
# 1                    0.321                         0.542       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
#    Perceptions of corruption  Dystopia + residual  Composite Score
# ...

# %% [markdown]
#  3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score

# %%
top_5 = df_sorted.head(5)
plt.figure(figsize=(10, 6))
plt.barh(top_5['Country name'], top_5['Composite Score'], color='skyblue')
plt.xlabel('Composite Score')
plt.title('Top 5 South Asian Countries by Composite Score')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# 4. Discuss whether the rankings based on the Composite Score align with the original Score- support your
#  discussion with some visualization plot.

# %%
import seaborn as sns

sns.pairplot(southasia[['Log GDP per capita', 'Social support', 'Healthy life expectancy', 'Composite Score']])
plt.show()
#discussion left to input

# %% [markdown]
# ## Task- 3- Outlier Detection:

# %% [markdown]
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita

# %%
# Calculate Q1, Q3, and IQR for GDP per Capita and Score
Q1_gdp = southasia['Log GDP per capita'].quantile(0.25)
Q3_gdp = southasia['Log GDP per capita'].quantile(0.75)
IQR_gdp = Q3_gdp - Q1_gdp

Q1_score = southasia['score'].quantile(0.25)
Q3_score = southasia['score'].quantile(0.75)
IQR_score = Q3_score - Q1_score

# Calculate outlier bounds
lower_bound_gdp = Q1_gdp - 1.5 * IQR_gdp
upper_bound_gdp = Q3_gdp + 1.5 * IQR_gdp

lower_bound_score = Q1_score - 1.5 * IQR_score
upper_bound_score = Q3_score + 1.5 * IQR_score

# Identify outliers
outliers_gdp = southasia[(southasia['Log GDP per capita'] < lower_bound_gdp) | (southasia['Log GDP per capita'] > upper_bound_gdp)]
outliers_score = southasia[(southasia['score'] < lower_bound_score) | (southasia['score'] > upper_bound_score)]

# Combine outliers from both columns
outliers = pd.concat([outliers_gdp, outliers_score]).drop_duplicates()

print("Outlier Countries:")
print(outliers[['Country name','score']])
# Out:
# Outlier Countries:
#   Country name  score
# 5  Afghanistan  1.721

# %% [markdown]
# 2. Define outliers using the 1.5 × IQR rule.

# %%
# dont know what its asking me to do

# %% [markdown]
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
#  in a different color.

# %%
# Identify outliers in the plot
outlier_countries = outliers['Country name']

# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(southasia['Log GDP per capita'], southasia['score'], label='Non-Outliers', color='blue')
plt.scatter(outliers['Log GDP per capita'], outliers['score'], label='Outliers', color='red')

# Labeling
plt.xlabel('Log GDP per capita')
plt.ylabel('score')
plt.title('Outlier Detection: GDP per capita vs. Score')
plt.legend()
plt.show()

# %% [markdown]
#  4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
#kinda hard to explain

# %% [markdown]
# ## Task- 4- Exploring Trends Across Metrics:

# %% [markdown]
#  1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
#  {pearson correlation} with the Score for South Asian countries.

# %%
# Step 1: Calculate the Pearson correlation between Score and two metrics (e.g., Freedom to Make Life Choices and Generosity)
correlation_freedom = southasia['Freedom to make life choices'].corr(southasia['score'])
correlation_generosity = southasia['Generosity'].corr(southasia['score'])

# Print the results
print(f"Pearson Correlation between Freedom to Make Life Choices and Score: {correlation_freedom}")
print(f"Pearson Correlation between Generosity and Score: {correlation_generosity}")
# Out:
# Pearson Correlation between Freedom to Make Life Choices and Score: 0.8005185224163315
# Pearson Correlation between Generosity and Score: 0.874512371253192

# %% [markdown]
# 2. Create scatter plots with trendlines for these metrics against the Score.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Step 2: Create scatter plots with trendlines
# Scatter plot for Freedom to Make Life Choices vs Score
plt.figure(figsize=(8, 6))
sns.regplot(x='Freedom to make life choices', y='score', data=southasia, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title('Freedom to Make Life Choices vs Score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')
plt.show()

# Scatter plot for Generosity vs Score
plt.figure(figsize=(8, 6))
sns.regplot(x='Generosity', y='score', data=df, scatter_kws={'color': 'green'}, line_kws={'color': 'red'})
plt.title('Generosity vs Score')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.show()

# %% [markdown]
#  3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
#  South Asian countries.

# %%
#dont know

# %% [markdown]
# ## Task- 5- Gap Analysis:

# %% [markdown]
#  1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
#  for each South Asian country.

# %%
# Add the GDP-Score Gap column
southasia['GDP-Score Gap'] = southasia['Log GDP per capita'] - southasia['score']

# Display the updated DataFrame
print(southasia[['Country name', 'Log GDP per capita', 'score', 'GDP-Score Gap']])
# Out:
#   Country name  Log GDP per capita  score  GDP-Score Gap
# 0        Nepal               0.965  5.158         -4.193
# 1     Pakistan               1.069  4.657         -3.588
# 2        India               1.166  4.054         -2.888
# 3    Sri Lanka               1.361  3.898         -2.537
# 4   Bangladesh               1.122  3.886         -2.764
# 5  Afghanistan               0.628  1.721         -1.093

# %% [markdown]
#  2. Rank the South Asian countries by this gap in both ascending and descending order.

# %%
# Rank countries by GDP-Score Gap in ascending order
ascending_gap = southasia.sort_values(by='GDP-Score Gap', ascending=True)

# Rank countries by GDP-Score Gap in descending order
descending_gap = southasia.sort_values(by='GDP-Score Gap', ascending=False)

# Display the ranked countries
print("Countries ranked by GDP-Score Gap (Ascending):")
print(ascending_gap[['Country name', 'GDP-Score Gap']])

print("\nCountries ranked by GDP-Score Gap (Descending):")
print(descending_gap[['Country name', 'GDP-Score Gap']])
# Out:
# Countries ranked by GDP-Score Gap (Ascending):
#   Country name  GDP-Score Gap
# 0        Nepal         -4.193
# 1     Pakistan         -3.588
# 2        India         -2.888
# 4   Bangladesh         -2.764
# 3    Sri Lanka         -2.537
# 5  Afghanistan         -1.093
#
# Countries ranked by GDP-Score Gap (Descending):
#   Country name  GDP-Score Gap
# 5  Afghanistan         -1.093
# 3    Sri Lanka         -2.537
# 4   Bangladesh         -2.764
# 2        India         -2.888
# 1     Pakistan         -3.588
# 0        Nepal         -4.193

# %% [markdown]
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.

# %%
# Extract the top 3 positive gaps
top_positive_gap = descending_gap.head(3)

# Create a bar chart for the top 3 positive gaps
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.barh(top_positive_gap['Country name'], top_positive_gap['GDP-Score Gap'], color='blue')
plt.title('Top 3 Countries with Largest Positive GDP-Score Gap')
plt.xlabel('GDP-Score Gap')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# Code for Negative Gaps

# %%
# Extract the top 3 negative gaps
top_negative_gap = ascending_gap.head(3)

# Create a bar chart for the top 3 negative gaps
plt.figure(figsize=(8, 6))
plt.barh(top_negative_gap['Country name'], top_negative_gap['GDP-Score Gap'], color='red')
plt.title('Top 3 Countries with Largest Negative GDP-Score Gap')
plt.xlabel('GDP-Score Gap')
plt.ylabel('Country')
plt.show()

# %% [markdown]
#  4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %% [markdown]
# Positive Gaps:
#
# Countries with higher GDP per Capita than their Score might have issues like income inequality, insufficient social services, or governance problems.
#
# Negative Gaps:
#
# Countries with higher Scores than GDP per Capita indicate strong social infrastructure, effective policies, or cultural factors fostering well-being despite limited economic resources.

# %% [markdown]
# # **3.3 Problem- 3- Comparative Analysis:**

# %% [markdown]
# ## Task- 1- Setup Task- Preparing the Middle Eastern Dataset:

# %% [markdown]
# 1. Similar in Task- 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
#  following list:
#  middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
#  "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
#  "United Arab Emirates", "Yemen"]

# %%
# Define the list of Middle Eastern countries
middle_east_countries = [
    "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon",
    "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
    "United Arab Emirates", "Yemen"
]

# Filter dataset for Middle Eastern countries
middle_east_df = df[df['Country name'].isin(middle_east_countries)]

middle_east_df.to_csv("middle_east_countries_data.csv", index=False)

# %% [markdown]
# 1. Descriptive Statistics:

# %%
mideast=pd.read_csv('/content/middle_east_countries_data.csv')
mideast.head(10)
# Out:
#            Country name  score  Log GDP per capita  Social support  \
# 0                Israel  7.341               1.803           1.513
# 1                Kuwait  6.951               1.845           1.364
# 2  United Arab Emirates  6.733               1.983           1.164
# 3          Saudi Arabia  6.594               1.842           1.361
# 4               Bahrain  5.959                 NaN             NaN
# 5                  Iraq  5.166               1.249           0.996
# 6                  Iran  4.923               1.435           1.136
# 7                Jordan  4.186               1.262           0.983
# 8                 Yemen  3.561               0.671           1.281
# 9               Lebanon  2.707               1.377           0.577
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.740                         0.641       0.153
# 1                    0.661                         0.827       0.200
# ...

# %%
# Descriptive statistics for South Asia and Middle East
south_asia_mean = southasia['score'].mean()
middle_east_mean = mideast['score'].mean()

south_asia_std = southasia['score'].std()
middle_east_std = mideast['score'].std()

print(f"South Asia - Mean: {south_asia_mean:.2f}, Std Dev: {south_asia_std:.2f}")
print(f"Middle East - Mean: {middle_east_mean:.2f}, Std Dev: {middle_east_std:.2f}")

# Determine the region with higher happiness scores
higher_region = "South Asia" if south_asia_mean > middle_east_mean else "Middle East"
print(f"Region with higher happiness scores on average: {higher_region}")
# Out:
# South Asia - Mean: 3.90, Std Dev: 1.18
# Middle East - Mean: 5.41, Std Dev: 1.57
# Region with higher happiness scores on average: Middle East

# %% [markdown]
# 2. Top and Bottom Performers:

# %%
# Top 3 and Bottom 3 performers in South Asia
south_asia_top = southasia.nlargest(3, 'score')
south_asia_bottom = southasia.nsmallest(3, 'score')

# Top 3 and Bottom 3 performers in Middle East
middle_east_top = mideast.nlargest(3, 'score')
middle_east_bottom = mideast.nsmallest(3, 'score')

print("South Asia - Top Performers:\n", south_asia_top[['Country name', 'score']])
print("South Asia - Bottom Performers:\n", south_asia_bottom[['Country name', 'score']])
print("Middle East - Top Performers:\n", middle_east_top[['Country name', 'score']])
print("Middle East - Bottom Performers:\n", middle_east_bottom[['Country name', 'score']])

# South Asia Bar Chart
plt.figure(figsize=(8, 6))
plt.bar(south_asia_top['Country name'], south_asia_top['score'], color='green', label='Top Performers')
plt.bar(south_asia_bottom['Country name'], south_asia_bottom['score'], color='red', label='Bottom Performers')
plt.title('Top and Bottom Performers in South Asia')
plt.xlabel('Country')
plt.ylabel('Score')
plt.legend()
plt.show()

# Middle East Bar Chart
plt.figure(figsize=(8, 6))
plt.bar(middle_east_top['Country name'], middle_east_top['score'], color='blue', label='Top Performers')
plt.bar(middle_east_bottom['Country name'], middle_east_bottom['score'], color='orange', label='Bottom Performers')
plt.title('Top and Bottom Performers in Middle East')
plt.xlabel('Country')
plt.ylabel('Score')
plt.legend()
plt.show()
# Out:
# South Asia - Top Performers:
#    Country name  score
# 0        Nepal  5.158
# 1     Pakistan  4.657
# 2        India  4.054
# South Asia - Bottom Performers:
#    Country name  score
# 5  Afghanistan  1.721
# 4   Bangladesh  3.886
# 3    Sri Lanka  3.898
# Middle East - Top Performers:
#             Country name  score
# 0                Israel  7.341
# 1                Kuwait  6.951
# 2  United Arab Emirates  6.733
# Middle East - Bottom Performers:
#    Country name  score
# 9      Lebanon  2.707
# 8        Yemen  3.561
# 7       Jordan  4.186

# %% [markdown]
#  3. Metric Comparisons:

# %%
# Compare metrics between South Asia and Middle East
metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']

south_asia_means = southasia[metrics].mean()
middle_east_means = mideast[metrics].mean()

x = np.arange(len(metrics))  # Label locations
width = 0.35  # Width of bars

plt.figure(figsize=(10, 6))
plt.bar(x - width/2, south_asia_means, width, label='South Asia', color='purple')
plt.bar(x + width/2, middle_east_means, width, label='Middle East', color='cyan')

plt.xticks(x, metrics)
plt.ylabel('Mean Value')
plt.title('Comparison of Key Metrics between South Asia and Middle East')
plt.legend()
plt.show()

# Largest disparity
disparity = abs(south_asia_means - middle_east_means)
print("Metric showing the largest disparity:", disparity.idxmax())
# Out:
# Metric showing the largest disparity: Social support

# %% [markdown]
# 4. Happiness Disparity:

# %%
# Calculate range and coefficient of variation (CV) for each region
south_asia_range = southasia['score'].max() - southasia['score'].min()
middle_east_range = mideast['score'].max() - mideast['score'].min()

south_asia_cv = southasia['score'].std() / southasia['score'].mean()
middle_east_cv = mideast['score'].std() / mideast['score'].mean()

print(f"South Asia - Range: {south_asia_range:.2f}, CV: {south_asia_cv:.2f}")
print(f"Middle East - Range: {middle_east_range:.2f}, CV: {middle_east_cv:.2f}")

greater_variability = "South Asia" if south_asia_cv > middle_east_cv else "Middle East"
print(f"Region with greater variability in happiness: {greater_variability}")
# Out:
# South Asia - Range: 3.44, CV: 0.30
# Middle East - Range: 4.63, CV: 0.29
# Region with greater variability in happiness: South Asia

# %% [markdown]
#  5. Correlation Analysis:

# %%
# Correlation of Score with metrics for South Asia
south_asia_corr = southasia[['score', 'Freedom to make life choices', 'Generosity']].corr()
print("South Asia Correlations:\n", south_asia_corr['score'])

# Correlation of Score with metrics for Middle East
middle_east_corr = mideast[['score', 'Freedom to make life choices', 'Generosity']].corr()
print("Middle East Correlations:\n", middle_east_corr['score'])

# South Asia Freedom vs. Score
sns.lmplot(x='Freedom to make life choices', y='score', data=southasia)
plt.title('South Asia: Freedom vs. Score')
plt.show()

# Middle East Freedom vs. Score
sns.lmplot(x='Freedom to make life choices', y='score', data=mideast)
plt.title('Middle East: Freedom vs. Score')
plt.show()
# Out:
# South Asia Correlations:
#  score                           1.000000
# Freedom to make life choices    0.800519
# Generosity                      0.874512
# Name: score, dtype: float64
# Middle East Correlations:
#  score                           1.000000
# Freedom to make life choices    0.863220
# Generosity                      0.627524
# Name: score, dtype: float64

# %% [markdown]
# Task 6: Outlier Detection

# %%
# Detect outliers using the 1.5 * IQR rule
for region, data in [("South Asia", southasia), ("Middle East", mideast)]:
    Q1 = data['score'].quantile(0.25)
    Q3 = data['score'].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = data[(data['score'] < lower_bound) | (data['score'] > upper_bound)]
    print(f"{region} Outliers:\n", outliers[['Country name', 'score']])
    print("\n")
# Out:
# South Asia Outliers:
#    Country name  score
# 5  Afghanistan  1.721
#
#
# Middle East Outliers:
#  Empty DataFrame
# Columns: [Country name, score]
# Index: []

# %% [markdown]
# Task 7: Visualization of Score Distribution

# %%
# Boxplot for Score comparison
plt.figure(figsize=(8, 6))
sns.boxplot(data=[southasia['score'], mideast ['score']], palette='Set2')
plt.xticks([0, 1], ['South Asia', 'Middle East'])
plt.ylabel('Score')
plt.title('Distribution of Happiness Score between South Asia and Middle East')
plt.show()
