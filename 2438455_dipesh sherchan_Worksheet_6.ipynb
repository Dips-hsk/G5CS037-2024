# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Load Titanic dataset
data = pd.read_csv('/content/drive/MyDrive/Datasets/Titanic-Dataset.csv')

# Example preprocessing (fill missing values and encode categorical data)
data['Age'] = data['Age'].fillna(data['Age'].mean())  # Assign result back to the column
data['Fare'] = data['Fare'].fillna(data['Fare'].mean())  # Assign result back to the column
data['Sex'] = data['Sex'].map({'male': 0, 'female': 1})  # Mapping is fine as it is
data['Embarked'] = data['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})
data['Embarked'] = data['Embarked'].fillna(2)  # Assign result back to the column

# %%
from sklearn.linear_model import LogisticRegression

# Logistic Regression
model = LogisticRegression()
model.fit(X, y)

# Get raw scores (logits)
logits = model.decision_function(X)  # For binary classification

# %%
import numpy as np

# Define softmax function
def softmax(logits):
    exp_logits = np.exp(logits - np.max(logits, axis=1, keepdims=True))  # Stability trick
    return exp_logits / np.sum(exp_logits, axis=1, keepdims=True)

# Prepare logits for softmax (as a 2D array with scores for both classes)
logits_2d = np.vstack([-logits, logits]).T

# Apply softmax
probabilities = softmax(logits_2d)

# Check probabilities (columns: P(Survived=0), P(Survived=1))
print(probabilities[:5])
# Out:
# [[0.98699047 0.01300953]
#  [0.00574786 0.99425214]
#  [0.39735219 0.60264781]
#  [0.01400411 0.98599589]
#  [0.99440004 0.00559996]]
